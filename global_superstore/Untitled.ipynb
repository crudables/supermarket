# %%
import pandas as pd

# %%
store = pd.read_csv('Global-Superstore.csv', encoding='unicode_escape') # encoding= 'unicode_escape' was used to solve the problem of inability of utf-8 to decode character

# %%
store.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
store.drop(columns=["Row ID","Order ID","Customer ID","Customer Name","Postal Code"], inplace=True)

# %%
store.columns = store.columns.map(lambda x:x.replace(" ","_"))
store.columns = store.columns.map(lambda x:x.lower())

# %%
store["Order_Date"] = pd.to_datetime(store["Order_Date"])
store["Ship_Date"] = pd.to_datetime(store["Ship_Date"])

# %%
store.sample(10)
# Out:
#       order_date  ship_date       ship_mode      segment         city  \
# 20078 2014-12-26 2014-12-29     First Class     Consumer      Hialeah
# 10321 2012-09-06 2012-09-12  Standard Class     Consumer    Geraldton
# 39205 2011-04-12 2011-04-16    Second Class  Home Office   Ponferrada
# 46438 2011-08-05 2011-08-08    Second Class     Consumer      Managua
# 31544 2012-09-22 2012-09-27    Second Class    Corporate  Khorramabad
# 38105 2014-05-29 2014-05-30     First Class     Consumer     Belgorod
# 32117 2014-12-29 2015-01-04  Standard Class     Consumer    Carrefour
# 51134 2014-09-19 2014-09-21     First Class     Consumer    Arlington
# 3217  2014-04-08 2014-04-12    Second Class    Corporate      Ivanovo
# 6990  2013-06-13 2013-06-18  Standard Class    Corporate      Jakarta
#
#                    state        country market          region  \
# 20078            Florida  United States     US           South
# 10321  Western Australia      Australia   APAC         Oceania
# ...

# %%
# The most expensive item sold over the period
store[store.sales ==store.sales.max()][["product_name","market","sales","profit","discount"]]
# Out:
#                                             product_name market     sales  \
# 12887  Cisco TelePresence System EX90 Videoconferenci...     US  22638.48
#
#           profit  discount
# 12887 -1811.0784       0.5

# %%
# sale of the most expensive item was at a loss.

# %%
store[store.sales ==store.sales.min()][["product_name","market","sales","profit","discount"]]
# Out:
#                                             product_name market  sales  \
# 51286  Hoover Replacement Belt for Commercial Guardsm...     US  0.444
#
#        profit  discount
# 51286   -1.11       0.8
